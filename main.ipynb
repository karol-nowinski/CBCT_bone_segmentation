# %% [markdown]
# # Imports

# %%
import torch
import glob
from Algorithms.Unet3D.unet3D import UNet3D
from Algorithms.Unet3D.mha_loader import MHA_Dataset
from torch.utils.data import DataLoader
from Algorithms.utils import Get_biggest_target_shape

# %% [markdown]
# # Loading toothFairy dataset

# %%
toothFairy2_image_path = "Data/ToothFairy2/imagesTr"
toothFairy2_labels_path = "Data/ToothFairy2/labelsTr"
target_shape = [304,512,512] # dividable by 16

# %%
mha_image_files = glob.glob(f"{toothFairy2_image_path}/*.mha")
mha_labels_files = glob.glob(f"{toothFairy2_labels_path}/*.mha")
print(mha_image_files)
print(mha_labels_files)
# Out:
# ['Data/ToothFairy2/imagesTr\\ToothFairy2F_001_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_002_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_003_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_004_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_005_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_006_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_007_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_008_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_009_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_010_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_011_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_012_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_013_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_014_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_015_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_016_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_018_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_020_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_021_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_022_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_023_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_024_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_025_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_026_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_027_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_028_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_029_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_030_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_031_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_032_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_033_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_034_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_036_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_037_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_038_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_039_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_040_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_041_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_043_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_044_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_045_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_046_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_047_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_048_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_049_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_050_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_051_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_052_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_053_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_054_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_055_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_056_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_057_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_058_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_059_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_060_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_061_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_062_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_063_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_064_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_065_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_066_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_067_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_001_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_002_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_003_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_004_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_005_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_006_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_007_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_008_0000.mha', 'Data/ToothFairy2/image ...
# ['Data/ToothFairy2/labelsTr\\ToothFairy2F_001.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_002.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_003.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_004.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_005.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_006.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_007.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_008.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_009.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_010.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_011.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_012.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_013.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_014.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_015.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_016.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_018.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_020.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_021.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_022.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_023.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_024.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_025.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_026.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_027.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_028.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_029.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_030.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_031.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_032.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_033.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_034.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_036.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_037.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_038.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_039.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_040.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_041.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_043.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_044.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_045.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_046.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_047.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_048.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_049.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_050.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_051.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_052.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_053.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_054.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_055.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_056.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_057.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_058.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_059.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_060.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_061.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_062.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_063.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_064.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_065.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_066.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_067.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_001.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_002.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_003.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_004.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_005.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_006.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_007.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_008.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_009.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_010.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_011.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_012.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_013.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_014.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_015.mha', 'Data/ToothFairy2/lab ...

# %%
dataset = MHA_Dataset(mha_image_files,mha_labels_files,target_shape)
dataLoader = DataLoader(dataset,batch_size=2,shuffle=True)

# %%
# gatting target size

target_size = Get_biggest_target_shape(mha_image_files)
print(target_size)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # gatting target size
# ----> 3 target_size = Get_biggest_target_shape(mha_image_files)
#       4 print(target_size)
#
# File d:\Magisterka\mgrRepo\Algorithms\utils.py:29, in Get_biggest_target_shape(image_files)
#      26 max_shape = np.array([0,0,0])
#      28 for image in image_files:
# ---> 29     image  = sitk.ReadImage(image)
#      30     image_size = sitk.GetArrayFromImage(image)
#      31     max_shape = np.maximum(max_shape,image_size.shape)
#
# File d:\Magisterka\mgrRepo\Algorithms\utils.py:29, in Get_biggest_target_shape(image_files)
#      26 max_shape = np.array([0,0,0])
#      28 for image in image_files:
# ---> 29     image  = sitk.ReadImage(image)
#      30     image_size = sitk.GetArrayFromImage(image)
#      31     max_shape = np.maximum(max_shape,image_size.shape)
#
# File _pydevd_bundle/pydevd_cython.pyx:1457, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:701, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1152, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1135, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:312, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File c:\Users\karno\miniconda3\envs\deep\lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2070, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2067             from_this_thread.append(frame_custom_thread_id)
#    2069     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2070         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2072 frames_list = None
#    2074 if keep_suspended:
#    2075     # This means that we should pause again after a set next statement.
#
# File c:\Users\karno\miniconda3\envs\deep\lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2106, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2103         self._call_input_hook()
#    2105     self.process_internal_commands()
# -> 2106     time.sleep(0.01)
#    2108 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2110 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
for images,labels in dataLoader:
    print(f"Image size: {images.shape}, label size: {labels.shape}")
    break
# Out:
# Image size: torch.Size([2, 1, 298, 512, 512]), label size: torch.Size([2, 298, 512, 512])

# %% [markdown]
# # 3D Unet

# %%
model = UNet3D(in_channels=1,out_channels=1,base_channels=32)

# %%
model = model.cuda()

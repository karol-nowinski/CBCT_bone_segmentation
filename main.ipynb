# %% [markdown]
# # Imports

# %%
import torch
import glob
from Algorithms.Unet3D.unet3D import UNet3D
from Algorithms.Unet3D.mha_loader import MHA_Dataset
from torch.utils.data import DataLoader
from Algorithms.utils import Get_biggest_target_shape
from Algorithms.trainer import UnetTrainer
from Datasets.SegmentationDataset import SegmentationDataset
import torchio as tio
from pathlib import Path

# %% [markdown]
# # Loading toothFairy dataset

# %%
toothFairy2_image_path = "Data/ToothFairy2/imagesTr"
toothFairy2_labels_path = "Data/ToothFairy2/labelsTr"
target_shape = [304,512,512] # dividable by 16

# %%
mha_image_files = glob.glob(f"{toothFairy2_image_path}/*.mha")
mha_labels_files = glob.glob(f"{toothFairy2_labels_path}/*.mha")
print(mha_image_files)
print(mha_labels_files)
# Out:
# ['Data/ToothFairy2/imagesTr\\ToothFairy2F_001_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_002_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_003_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_004_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_005_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_006_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_007_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_008_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_009_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_010_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_011_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_012_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_013_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_014_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_015_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_016_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_018_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_020_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_021_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_022_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_023_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_024_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_025_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_026_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_027_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_028_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_029_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_030_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_031_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_032_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_033_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_034_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_036_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_037_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_038_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_039_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_040_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_041_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_043_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_044_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_045_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_046_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_047_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_048_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_049_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_050_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_051_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_052_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_053_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_054_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_055_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_056_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_057_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_058_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_059_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_060_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_061_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_062_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_063_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_064_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_065_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_066_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2F_067_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_001_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_002_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_003_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_004_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_005_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_006_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_007_0000.mha', 'Data/ToothFairy2/imagesTr\\ToothFairy2P_008_0000.mha', 'Data/ToothFairy2/image ...
# ['Data/ToothFairy2/labelsTr\\ToothFairy2F_001.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_002.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_003.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_004.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_005.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_006.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_007.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_008.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_009.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_010.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_011.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_012.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_013.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_014.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_015.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_016.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_018.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_020.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_021.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_022.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_023.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_024.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_025.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_026.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_027.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_028.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_029.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_030.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_031.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_032.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_033.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_034.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_036.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_037.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_038.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_039.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_040.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_041.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_043.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_044.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_045.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_046.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_047.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_048.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_049.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_050.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_051.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_052.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_053.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_054.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_055.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_056.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_057.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_058.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_059.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_060.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_061.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_062.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_063.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_064.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_065.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_066.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2F_067.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_001.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_002.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_003.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_004.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_005.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_006.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_007.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_008.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_009.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_010.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_011.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_012.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_013.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_014.mha', 'Data/ToothFairy2/labelsTr\\ToothFairy2P_015.mha', 'Data/ToothFairy2/lab ...

# %%
dataset = MHA_Dataset(mha_image_files,mha_labels_files,target_shape)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size

print(train_size,val_size)

dataLoader = DataLoader(dataset,batch_size=2,shuffle=True)

# %%
# getting target size

target_size = Get_biggest_target_shape(mha_image_files)
print(target_size)

# %%
for images,labels in dataLoader:
    print(f"Image size: {images.shape}, label size: {labels.shape}")
    break
# Out:
# Image size: torch.Size([2, 1, 298, 512, 512]), label size: torch.Size([2, 298, 512, 512])

# %% [markdown]
# ## new DataLoader test

# %%
images = ["Data/ChinaCBCT/img/1000813648_20180116.nii.gz",
          "Data/ChinaCBCT/img/1000889125_20171009.nii.gz",
          "Data/ChinaCBCT/img/1000889125_20171016.nii.gz"
          ]

masks = ["Data/ChinaCBCT/label/1000813648_20180116.nii.gz",
         "Data/ChinaCBCT/label/1000889125_20171009.nii.gz",
         "Data//ChinaCBCT/label/1000889125_20171016.nii.gz"
        ]

target_shape_val = (400,400,280)

transform_val = tio.RandomFlip(axes=(0, 1, 2), flip_probability=0.5)

# %%
dataset = SegmentationDataset(images,masks,target_shape = target_shape_val,transform = transform_val)
loader = DataLoader(dataset,batch_size=1,shuffle=False)

# %%
image_tensor, mask_tensor = next(iter(loader)) # pobranie batcha
print("Obraz shape:", image_tensor.shape)  # ➜ [1, 1, D, H, W]
print("Maska shape:", mask_tensor.shape)   # ➜ [1, 1, D, H, W]
# Out:
# Obraz shape: torch.Size([1, 1, 400, 400, 280])
# Maska shape: torch.Size([1, 1, 400, 400, 280])

# %% [markdown]
# ## Przetestowanie wytrenowania 3 zdjęć na Unet3D

# %%
image_paths = sorted([str(p) for p in Path('Data/ChinaCBCT/img').glob('*.nii.gz')])
masks_paths = sorted([str(p) for p in Path('Data/ChinaCBCT/label').glob('*.nii.gz')])

print(image_paths)
print(masks_paths)
# Out:
# ['Data\\ChinaCBCT\\img\\1000813648_20180116.nii.gz', 'Data\\ChinaCBCT\\img\\1000889125_20171009.nii.gz', 'Data\\ChinaCBCT\\img\\1000889125_20171016.nii.gz', 'Data\\ChinaCBCT\\img\\1000889125_20180109.nii.gz', 'Data\\ChinaCBCT\\img\\1000889125_20180521.nii.gz', 'Data\\ChinaCBCT\\img\\1000889125_20181106.nii.gz', 'Data\\ChinaCBCT\\img\\1000889125_20190408.nii.gz', 'Data\\ChinaCBCT\\img\\1000889125_20191101.nii.gz', 'Data\\ChinaCBCT\\img\\1000889125_20200421.nii.gz', 'Data\\ChinaCBCT\\img\\1000915187_20180115.nii.gz', 'Data\\ChinaCBCT\\img\\1000915187_20191217.nii.gz', 'Data\\ChinaCBCT\\img\\1000966359_20180113.nii.gz', 'Data\\ChinaCBCT\\img\\1000971031_20180112.nii.gz', 'Data\\ChinaCBCT\\img\\1000983254_20180109.nii.gz', 'Data\\ChinaCBCT\\img\\1000983254_20180904.nii.gz', 'Data\\ChinaCBCT\\img\\1000995722_20180112.nii.gz', 'Data\\ChinaCBCT\\img\\1001009635_20180116.nii.gz', 'Data\\ChinaCBCT\\img\\1001012179_20180110.nii.gz', 'Data\\ChinaCBCT\\img\\1001012179_20180116.nii.gz', 'Data\\ChinaCBCT\\img\\1001020384_20180114.nii.gz', 'Data\\ChinaCBCT\\img\\1001022839_20180110.nii.gz', 'Data\\ChinaCBCT\\img\\1001022839_20180225.nii.gz', 'Data\\ChinaCBCT\\img\\1001028863_20180115.nii.gz', 'Data\\ChinaCBCT\\img\\1001055861_20180109.nii.gz', 'Data\\ChinaCBCT\\img\\1001068663_20180116.nii.gz', 'Data\\ChinaCBCT\\img\\1001111103_20180114.nii.gz', 'Data\\ChinaCBCT\\img\\1001127112_20180109.nii.gz', 'Data\\ChinaCBCT\\img\\1001133637_20180110.nii.gz', 'Data\\ChinaCBCT\\img\\1001142392_20180110.nii.gz', 'Data\\ChinaCBCT\\img\\1001142392_20180116.nii.gz', 'Data\\ChinaCBCT\\img\\1001142392_20180511.nii.gz', 'Data\\ChinaCBCT\\img\\1001152328_20150714.nii.gz', 'Data\\ChinaCBCT\\img\\1001152328_20180112.nii.gz', 'Data\\ChinaCBCT\\img\\1001152328_20180306.nii.gz', 'Data\\ChinaCBCT\\img\\1001152328_20180910.nii.gz', 'Data\\ChinaCBCT\\img\\1001162439_20140520.nii.gz', 'Data\\ChinaCBCT\\img\\1001162439_20150708.nii.gz', 'Data\\ChinaCBCT\\img\\1001162439_20180110.nii.gz', 'Data\\ChinaCBCT\\img\\1001162439_20200910.nii.gz', 'Data\\ChinaCBCT\\img\\1001172283_20180110.nii.gz', 'Data\\ChinaCBCT\\img\\1001172283_20190622.nii.gz', 'Data\\ChinaCBCT\\img\\1001173165_20171205.nii.gz', 'Data\\ChinaCBCT\\img\\1001173165_20180115.nii.gz', 'Data\\ChinaCBCT\\img\\1001173165_20180521.nii.gz', 'Data\\ChinaCBCT\\img\\1001213121_20180115.nii.gz', 'Data\\ChinaCBCT\\img\\1001218388_20161024.nii.gz', 'Data\\ChinaCBCT\\img\\1001218388_20171102.nii.gz', 'Data\\ChinaCBCT\\img\\1001218388_20180109.nii.gz', 'Data\\ChinaCBCT\\img\\1001223657_20180112.nii.gz', 'Data\\ChinaCBCT\\img\\1001224969_20171019.nii.gz', 'Data\\ChinaCBCT\\img\\1001224969_20180116.nii.gz', 'Data\\ChinaCBCT\\img\\1001224969_20180330.nii.gz', 'Data\\ChinaCBCT\\img\\1001232054_20171211.nii.gz', 'Data\\ChinaCBCT\\img\\1001232054_20180109.nii.gz', 'Data\\ChinaCBCT\\img\\1001247962_20180115.nii.gz', 'Data\\ChinaCBCT\\img\\1001250407_20180115.nii.gz', 'Data\\ChinaCBCT\\img\\1001250407_20190306.nii.gz', 'Data\\ChinaCBCT\\img\\1001250407_20190923.nii.gz', 'Data\\ChinaCBCT\\img\\1001250407_20200403.nii.gz', 'Data\\ChinaCBCT\\img\\1001261667_20180109.nii.gz', 'Data\\ChinaCBCT\\img\\1001261667_20210221.nii.gz', 'Data\\ChinaCBCT\\img\\1001263197_20180115.nii.gz', 'Data\\ChinaCBCT\\img\\1001263197_20180208.nii.gz', 'Data\\ChinaCBCT\\img\\1001263197_20180730.nii.gz', 'Data\\ChinaCBCT\\img\\1001275319_20180114.nii.gz', 'Data\\ChinaCBCT\\img\\1001277267_20180112.nii.gz', 'Data\\ChinaCBCT\\img\\1001282649_20180104.nii.gz', 'Data\\ChinaCBCT\\img\\1001287535_20180108.nii.gz', 'Data\\ChinaCBCT\\img\\1001287535_20180116.nii.gz', 'Data\\ChinaCBCT\\img\\1001291347_20180112.nii.gz', 'Data\\ChinaCBCT\\img\\1001327709_20180115.nii.gz', 'Data\\ChinaCBCT\\img\\1001377656_20171105.nii.gz', 'Data\\ChinaCBCT\\img\\1001377656_20180116.nii.gz', 'Data\\ChinaCBCT\\img\\1001381644_20180112.nii.gz', 'Data\\ChinaCBCT\\img\\1001382496_20180112.nii.gz', 'Data\\ChinaCBCT\\img\\1001382496_20180423.nii.gz', 'Data\\ChinaCBCT\\img\\1001382496_20201206.nii. ...
# ['Data\\ChinaCBCT\\label\\1000813648_20180116.nii.gz', 'Data\\ChinaCBCT\\label\\1000889125_20171009.nii.gz', 'Data\\ChinaCBCT\\label\\1000889125_20171016.nii.gz', 'Data\\ChinaCBCT\\label\\1000889125_20180109.nii.gz', 'Data\\ChinaCBCT\\label\\1000889125_20180521.nii.gz', 'Data\\ChinaCBCT\\label\\1000889125_20181106.nii.gz', 'Data\\ChinaCBCT\\label\\1000889125_20190408.nii.gz', 'Data\\ChinaCBCT\\label\\1000889125_20191101.nii.gz', 'Data\\ChinaCBCT\\label\\1000889125_20200421.nii.gz', 'Data\\ChinaCBCT\\label\\1000915187_20180115.nii.gz', 'Data\\ChinaCBCT\\label\\1000915187_20191217.nii.gz', 'Data\\ChinaCBCT\\label\\1000966359_20180113.nii.gz', 'Data\\ChinaCBCT\\label\\1000971031_20180112.nii.gz', 'Data\\ChinaCBCT\\label\\1000983254_20180109.nii.gz', 'Data\\ChinaCBCT\\label\\1000983254_20180904.nii.gz', 'Data\\ChinaCBCT\\label\\1000995722_20180112.nii.gz', 'Data\\ChinaCBCT\\label\\1001009635_20180116.nii.gz', 'Data\\ChinaCBCT\\label\\1001012179_20180110.nii.gz', 'Data\\ChinaCBCT\\label\\1001012179_20180116.nii.gz', 'Data\\ChinaCBCT\\label\\1001020384_20180114.nii.gz', 'Data\\ChinaCBCT\\label\\1001022839_20180110.nii.gz', 'Data\\ChinaCBCT\\label\\1001022839_20180225.nii.gz', 'Data\\ChinaCBCT\\label\\1001028863_20180115.nii.gz', 'Data\\ChinaCBCT\\label\\1001055861_20180109.nii.gz', 'Data\\ChinaCBCT\\label\\1001068663_20180116.nii.gz', 'Data\\ChinaCBCT\\label\\1001111103_20180114.nii.gz', 'Data\\ChinaCBCT\\label\\1001127112_20180109.nii.gz', 'Data\\ChinaCBCT\\label\\1001133637_20180110.nii.gz', 'Data\\ChinaCBCT\\label\\1001142392_20180110.nii.gz', 'Data\\ChinaCBCT\\label\\1001142392_20180116.nii.gz', 'Data\\ChinaCBCT\\label\\1001142392_20180511.nii.gz', 'Data\\ChinaCBCT\\label\\1001152328_20150714.nii.gz', 'Data\\ChinaCBCT\\label\\1001152328_20180112.nii.gz', 'Data\\ChinaCBCT\\label\\1001152328_20180306.nii.gz', 'Data\\ChinaCBCT\\label\\1001152328_20180910.nii.gz', 'Data\\ChinaCBCT\\label\\1001162439_20140520.nii.gz', 'Data\\ChinaCBCT\\label\\1001162439_20150708.nii.gz', 'Data\\ChinaCBCT\\label\\1001162439_20180110.nii.gz', 'Data\\ChinaCBCT\\label\\1001162439_20200910.nii.gz', 'Data\\ChinaCBCT\\label\\1001172283_20180110.nii.gz', 'Data\\ChinaCBCT\\label\\1001172283_20190622.nii.gz', 'Data\\ChinaCBCT\\label\\1001173165_20171205.nii.gz', 'Data\\ChinaCBCT\\label\\1001173165_20180115.nii.gz', 'Data\\ChinaCBCT\\label\\1001173165_20180521.nii.gz', 'Data\\ChinaCBCT\\label\\1001213121_20180115.nii.gz', 'Data\\ChinaCBCT\\label\\1001218388_20161024.nii.gz', 'Data\\ChinaCBCT\\label\\1001218388_20171102.nii.gz', 'Data\\ChinaCBCT\\label\\1001218388_20180109.nii.gz', 'Data\\ChinaCBCT\\label\\1001223657_20180112.nii.gz', 'Data\\ChinaCBCT\\label\\1001224969_20180330.nii.gz', 'Data\\ChinaCBCT\\label\\1001232054_20171211.nii.gz', 'Data\\ChinaCBCT\\label\\1001232054_20180109.nii.gz', 'Data\\ChinaCBCT\\label\\1001247962_20180115.nii.gz', 'Data\\ChinaCBCT\\label\\1001250407_20180115.nii.gz', 'Data\\ChinaCBCT\\label\\1001250407_20190306.nii.gz', 'Data\\ChinaCBCT\\label\\1001250407_20190923.nii.gz', 'Data\\ChinaCBCT\\label\\1001250407_20200403.nii.gz', 'Data\\ChinaCBCT\\label\\1001261667_20180109.nii.gz', 'Data\\ChinaCBCT\\label\\1001261667_20210221.nii.gz', 'Data\\ChinaCBCT\\label\\1001263197_20180115.nii.gz', 'Data\\ChinaCBCT\\label\\1001263197_20180208.nii.gz', 'Data\\ChinaCBCT\\label\\1001263197_20180730.nii.gz', 'Data\\ChinaCBCT\\label\\1001275319_20180114.nii.gz', 'Data\\ChinaCBCT\\label\\1001277267_20180112.nii.gz', 'Data\\ChinaCBCT\\label\\1001282649_20180104.nii.gz', 'Data\\ChinaCBCT\\label\\1001287535_20180108.nii.gz', 'Data\\ChinaCBCT\\label\\1001287535_20180116.nii.gz', 'Data\\ChinaCBCT\\label\\1001291347_20180112.nii.gz', 'Data\\ChinaCBCT\\label\\1001327709_20180115.nii.gz', 'Data\\ChinaCBCT\\label\\1001377656_20171105.nii.gz', 'Data\\ChinaCBCT\\label\\1001377656_20180116.nii.gz', 'Data\\ChinaCBCT\\label\\1001381644_20180112.nii.gz', 'Data\\ChinaCBCT\\label\\1001382496_20180112.nii.gz', 'Data\\ChinaCBCT\\label\\1001382496_20180423.nii.gz', 'Da ...

# %%
# dane do trenowania / podział testowy
image_paths = image_paths[:10]
masks_paths = masks_paths[:10]

train_image_paths = image_paths[:8]
train_mask_paths = masks_paths[:8]

val_image_paths = image_paths[8:]
val_mask_paths = masks_paths[8:]

## Parametry sieci
batch_siez = 1
device = 'cuda' if torch.cuda.is_available() else 'cpu'
num_epochs = 40
lr = 1e-4 # learning rate
target_shape_val = (400,400,280)

# %%
train_transform = tio.Compose([
    tio.RandomFlip(axes=(0, 1, 2)),
    tio.RandomAffine(scales=(0.9, 1.1), degrees=10, translation=5),
    tio.RandomNoise(std=0.01)
])

# %%
train_dataset = SegmentationDataset(train_image_paths, train_mask_paths,
                                        target_shape=target_shape_val,
                                        transform=train_transform)

val_dataset = SegmentationDataset(val_image_paths, val_mask_paths,
                                      target_shape=target_shape_val,
                                      transform=None)

# %%
model = UNet3D(in_channels=1,out_channels=33)

# %% [markdown]
# # 3D Unet

# %%
model = UNet3D(in_channels=1,out_channels=1,base_channels=32)

# %%
model = model.cuda()

# %%
trainer = UnetTrainer(model=model,train_dataset=tra )
